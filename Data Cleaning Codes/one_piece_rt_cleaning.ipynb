# %%
import pandas as pd
import pandasql as ps
import numpy as np
import time
import re

# %% [markdown]
# ## Load Dataframe

# %%
# Open dataframe

one_piece_rt_df = pd.read_csv("one_piece_RT.csv")

# %%
print(len(one_piece_rt_df))
# Out:
# 1230

# %%
one_piece_rt_df.head(5)
# Out:
#    Unnamed: 0    User_IDs Timestamps  \
# 0           0      Deen W     Dec 20
# 1           1       Gol D      Dec 6
# 2           2  Celeborn G     Nov 30
# 3           3    Robert M     Oct 27
# 4           4    Tygari D     Sep 30
#
#                                              Reviews           Source
# 0  One of the best manga adaptations of all time....  Rotten Tomatoes
# 1  Best Anime Live Action Adaptation of All Time....  Rotten Tomatoes
# 2  How were they able to cram so much cringe into...  Rotten Tomatoes
# 3  One Piece is an incredibly well done show. It ...  Rotten Tomatoes
# 4  i am not a one piece fan. but this live action...  Rotten Tomatoes

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### I. Checking Data

# %%
# Check duplicated values

print(one_piece_rt_df['Reviews'].duplicated().sum())
# Out:
# 20

# %%
# There are 20 duplicated reviews

duplicated_rows = one_piece_rt_df[one_piece_rt_df['Reviews'].duplicated(keep=False)]

duplicated_rows
# Out:
#       Unnamed: 0           User_IDs  Timestamps  \
# 1150        1150           Austin W  09/01/2023
# 1151        1151             Mack S  09/01/2023
# 1152        1152                A L  09/01/2023
# 1153        1153             John R  09/01/2023
# 1154        1154             Faiber  09/01/2023
# 1155        1155                C J  09/01/2023
# 1156        1156             Edox25  09/01/2023
# 1157        1157             FENG C  09/01/2023
# 1158        1158             Arga L  09/01/2023
# 1159        1159  Maxim-Alexandre L  09/01/2023
# 1160        1160             Cora J  09/01/2023
# 1161        1161              Sid P  09/01/2023
# 1162        1162           BH_an1me  09/01/2023
# 1163        1163             ALDRIN  09/01/2023
# 1164        1164             Nora M  09/01/2023
# 1165        1165            Henry M  09/01/2023
# 1166        1166             Nazz M  09/01/2023
# 1167        1167           Jordan M  09/01/2023
# 1168        1168           Angelo P  09/01/2023
# 1169        1169            Anvee 4  09/01/2023
# 1170        1170           Austin W  09/01/2023
# 1171        1171             Mack S  09/01/2023
# 1172        1172                A L  09/01/2023
# 1173        1173             John R  09/01/2023
# 1174        1174             Faiber  09/01/2023
# 1175        1175                C J  09/01/2023
# 1176        1176             Edox25  09/01/2023
# 1177        1177             FENG C  09/01/2023
# 1178        1178             Arga L  09/01/2023
# 1179        1179  Maxim-Alexandre L  09/01/2023
# 1180        1180             Cora J  09/01/2023
# 1181        1181              Sid P  09/01/2023
# 1182        1182           BH_an1me  09/01/2023
# 1183        1183             ALDRIN  09/01/2023
# 1184        1184             Nora M  09/01/2023
# 1185        1185            Henry M  09/01/2023
# 1186        1186             Nazz M  09/01/2023
# 1187        1187           Jordan M  09/01/2023
# 1188        1188           Angelo P  09/01/2023
# 1189        1189            Anvee 4  09/01/2023
#
#                                                 Reviews           Source
# 1150  Honestly? I couldn't have asked for a better a...  Rotten Tomatoes
# 1151  Actually the best live action anime adaptation...  Rotten Tomatoes
# 1152  Excellent adaptation with tweaks made that dev...  Rotten Tomatoes
# 1153  There were some corny, clunky bits here and th...  Rotten Tomatoes
# 1154  No se esperaba mucho de un live action. Pero l...  Rotten Tomatoes
# 1155  Awesome anime adaptation and in-general just a...  Rotten Tomatoes
# 1156                             This series is amazing  Rotten Tomatoes
# 1157  Excellent casting, embarrassing acting, very d...  Rotten Tomatoes
# 1158  it's just good,but it's can be better some thi...  Rotten Tomatoes
# 1159  It's been a cliché for years now that an anime...  Rotten Tomatoes
# 1160  Exceeded my expectations, great acting, music,...  Rotten Tomatoes
# 1161  One Piece Live Action Series has adapted the M...  Rotten Tomatoes
# 1162  This live action adaptation is probably one of...  Rotten Tomatoes
# 1163  The series have some storylines skipped and ch...  Rotten Tomatoes
# 1164  Have been reading and watching One Piece since...  Rotten Tomatoes
# 1165  The spirit of one-piece manga is there, The fe...  Rotten Tomatoes
# 1166  Soy ULTRA fan de One Piece y puedo decir que l...  Rotten Tomatoes
# 1167  Amazing! This is exactly what was needed from ...  Rotten Tomatoes
# 1168  Didn't expect this to be so good. I never read...  Rotten Tomatoes
# 1169  better than I thought, give it a try if ur on ...  Rotten Tomatoes
# 1170  Honestly? I couldn't have asked for a better a...  Rotten Tomatoes
# 1171  Actually the best live action anime adaptation...  Rotten Tomatoes
# 1172  Excellent adaptation with tweaks made that dev...  Rotten Tomatoes
# 1173  There were some corny, clunky bits here and th...  Rotten Tomatoes
# 1174  No se esperaba mucho de un live action. Pero l...  Rotten Tomatoes
# 1175  Awesome anime adaptation and in-general just a...  Rotten Tomatoes
# 1176                             This series is amazing  Rotten Tomatoes
# 1177  Excellent casting, embarrassing acting, very d...  Rotten Tomatoes
# 1178  it's just good,but it's can be better some thi...  Rotten Tomatoes
# 1179  It's been a cliché for years now that an anime...  Rotten Tomatoes
# 1180  Exceeded my expectations, great acting, music,...  Rotten Tomatoes
# 1181  One Piece Live Action Series has adapted the M...  Rotten Tomatoes
# 1182  This live action adaptation is probably one of...  Rotten Tomatoes
# 1183  The series have some storylines skipped and ch...  Rotten Tomatoes
# 1184  Have been reading and watching One Piece since...  Rotten Tomatoes
# 1185  The spirit of one-piece manga is there, The fe...  Rotten Tomatoes
# 1186  Soy ULTRA fan de One Piece y puedo decir que l...  Rotten Tomatoes
# 1187  Amazing! This is exactly what was needed from ...  Rotten Tomatoes
# 1188  Didn't expect this to be so good. I never read...  Rotten Tomatoes
# 1189  better than I thought, give it a try if ur on ...  Rotten Tomatoes

# %%
# There are 20 duplicated rows in database
# Need to drop them

one_piece_rt_df = one_piece_rt_df.drop_duplicates(['Reviews'], keep = 'first')

# %%
# Check if duplicated values are droped

len(one_piece_rt_df)
# Out:
# 1210

# %%
# Before cleaning data, make sure there's no empty values

def missing_values(df):
    columns = df.columns
    for c in columns:
        missing = df[c].isnull().sum()
        print(f"The column, {c}, has {missing} values.")

# %%
missing_values(one_piece_rt_df)
# Out:
# The column, Unnamed: 0, has 0 values.
# The column, User_IDs, has 2 values.
# The column, Timestamps, has 0 values.
# The column, Reviews, has 0 values.
# The column, Source, has 0 values.

# %%
# We have 2 missing values on User IDs.
# However, since this is about sentiment analysis, decided to get rid of the User_IDs column as 1st cleaning

one_piece_rt_df = one_piece_rt_df.drop(["Unnamed: 0", "User_IDs"], axis=1)

# %%
one_piece_rt_df.head(5)
# Out:
#   Timestamps                                            Reviews  \
# 0     Dec 20  One of the best manga adaptations of all time....
# 1      Dec 6  Best Anime Live Action Adaptation of All Time....
# 2     Nov 30  How were they able to cram so much cringe into...
# 3     Oct 27  One Piece is an incredibly well done show. It ...
# 4     Sep 30  i am not a one piece fan. but this live action...
#
#             Source
# 0  Rotten Tomatoes
# 1  Rotten Tomatoes
# 2  Rotten Tomatoes
# 3  Rotten Tomatoes
# 4  Rotten Tomatoes

# %% [markdown]
# ### II. Change Timestamps to Proper Format

# %%
# As some of them are partially recorded, they need to be changed to proper format

def time_conversion(text):
    if pd.isna(text):
        return pd.NaT
    
    now = pd.Timestamp.now()

    day_match = re.search(r'(\d+)\s*d', text)
    if day_match:
        day = int(day_match.group(1))
        return pd.Timestamp.now() - pd.to_timedelta(day, unit='d')
    
    partial_date = re.match(r'^[A-Za-z]{3}\s+\d{1,2}$', text)
    if partial_date:
        return pd.to_datetime(f"{text} {now.year}", format="%b %d %Y", errors="coerce")
    
    else:
        return pd.to_datetime(text, errors="coerce")

# %%
one_piece_rt_df['review_dates'] = one_piece_rt_df['Timestamps'].apply(time_conversion)

one_piece_rt_df['review_dates'] = one_piece_rt_df['review_dates'].dt.strftime('%Y-%m-%d')

# %%
# Once review_dates are all changed, drop Timestamps

one_piece_rt_df = one_piece_rt_df.drop("Timestamps", axis=1)

# %% [markdown]
# ### III. VADER for Checking Sentiment

# %%
# Now it's time to check the sentiment using VADER

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiment_vader = SentimentIntensityAnalyzer()

one_piece_rt_df['vader_score_review'] = one_piece_rt_df['Reviews'].apply(lambda text: sentiment_vader.polarity_scores(text)['compound'])

# %%
def sentiment_category_vader(sentiment):
        if sentiment >= 0.05:
            return "Positive"
        elif sentiment <= -0.05:
            return "Negative"
        else:
            return "Neutral"
        
one_piece_rt_df['vader_sentiment_review'] = one_piece_rt_df['vader_score_review'].apply(sentiment_category_vader)

# %%
one_piece_rt_df.head(3)
# Out:
#                                              Reviews           Source  \
# 0  One of the best manga adaptations of all time....  Rotten Tomatoes
# 1  Best Anime Live Action Adaptation of All Time....  Rotten Tomatoes
# 2  How were they able to cram so much cringe into...  Rotten Tomatoes
#
#   review_dates  vader_score_review vader_sentiment_review
# 0   2026-12-20              0.8402               Positive
# 1   2026-12-06              0.6696               Positive
# 2   2026-11-30              0.4601               Positive

# %% [markdown]
# ### IV. Last Step for Data Cleaning

# %%
# We all have necessary data, so let's organize dataframe by using SQL

one_piece_rt_df_final = ps.sqldf("select [review_dates], [Reviews], [vader_score_review], [vader_sentiment_review], [Source] from one_piece_rt_df")

# %%
# Finally, standardize column names by changing them to small letters

one_piece_rt_df_final = one_piece_rt_df_final.rename(columns = {'Reviews':'reviews', 'Source':'source'})

# %% [markdown]
# ## Finalizing Data Cleaning Process & End

# %%
one_piece_rt_df_final.to_csv('one_piece_rt_df_cleaned.csv', index=False)
